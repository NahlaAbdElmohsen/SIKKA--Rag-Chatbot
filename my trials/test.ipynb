# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_excel('new_data.xlsx')
data.head()
# Out:
#   governate              city station_name destination  price
# 0   القاهرة  حى الساحل - شبرا         عبود       دمياط  110.0
# 1   القاهرة  حى الساحل - شبرا         عبود    رأس البر  140.0
# 2   القاهرة  حى الساحل - شبرا         عبود   كفر الشيخ   59.0
# 3   القاهرة  حى الساحل - شبرا         عبود        قلين   60.0
# 4   القاهرة  حى الساحل - شبرا         عبود     الحامول   65.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1409 entries, 0 to 1408
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   governate     1409 non-null   object
#  1   city          1409 non-null   object
#  2   station_name  1409 non-null   object
#  3   destination   1409 non-null   object
#  4   price         1409 non-null   float64
# dtypes: float64(1), object(4)
# memory usage: 55.2+ KB

# %%
data.describe()
# Out:
#              price
# count  1409.000000
# mean     25.110539
# std      41.216828
# min       3.000000
# 25%       5.500000
# 50%       8.000000
# 75%      29.500000
# max     390.000000

# %%
data.describe(include='object')
# Out:
#        governate      city station_name destination
# count       1409      1409         1409        1409
# unique         5        48          129         839
# top     الدقهلية  بنى سويف     بنى سويف  الإسكندرية
# freq         435        70           70          23

# %%
data.isna().sum()
# Out:
# governate       0
# city            0
# station_name    0
# destination     0
# price           0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 1

# %%
data[data.duplicated()==True]
# Out:
#     governate city station_name destination  price
# 305  بنى سويف  ببا          ببا    البرانقة    5.0

# %%
data[data['city']=='ببا']
# Out:
#     governate city station_name      destination  price
# 272  بنى سويف  ببا          ببا           المنيب   69.0
# 273  بنى سويف  ببا          ببا         بنى سويف    8.0
# 274  بنى سويف  ببا          ببا            المرج   77.0
# 275  بنى سويف  ببا          ببا       الإسكندرية  204.0
# 276  بنى سويف  ببا          ببا         السلطانى    5.0
# 277  بنى سويف  ببا          ببا         بنى قاسم    5.0
# 278  بنى سويف  ببا          ببا         البرانقة    5.0
# 279  بنى سويف  ببا          ببا    طنسا بنى مالو    5.0
# 280  بنى سويف  ببا          ببا       منشأة عاصم    5.0
# 281  بنى سويف  ببا          ببا      سدس الأمراء    5.0
# 282  بنى سويف  ببا          ببا             شوشة    5.0
# 283  بنى سويف  ببا          ببا           هربشنت    5.0
# 284  بنى سويف  ببا          ببا             سراج    5.0
# 285  بنى سويف  ببا          ببا         الشراهنة    5.0
# 286  بنى سويف  ببا          ببا            الفشن    6.0
# 287  بنى سويف  ببا          ببا            طرشوب    5.0
# ...

# %%
data.drop_duplicates(inplace=True)

# %%
data['city'].unique()
# Out:
# array(['حى الساحل - شبرا', 'السلام', 'المرج', 'حلوان', 'بنى سويف', 'ببا',
#        'الفشن', 'إهناسيا', 'سمسطا', 'ناصر ', 'الواسطى', 'كفر سعد',
#        'كفر البطيخ', 'كفر الغاب', 'دمياط الجديدة', 'دمياط',
#        'ميت أبو غالب', 'رأس البر', 'الزرقا', 'الوسطانى', 'فارسكور',
#        'الروضة', 'الباجور', 'تلا', 'السادات', 'سرس الليان', 'منوف',
#        'قويسنا', 'الشهداء', 'بركة السبع', 'شبين الكوم', 'أشمون',
#        'المنصورة', 'طلخا', 'أجا', 'ميت غمر', 'دكرنس', 'منية النصر',
#        'ميت سلسيل', 'الجمالية', 'المنزلة', 'نبروه', 'بلقاس', 'شربين',
#        'جمصة', 'السنبلاوين', 'تمى الأمديد', 'بنى عبيد'], dtype=object)

# %%
data['city']=data['city'].str.strip()
data['city'].unique()
# Out:
# array(['حى الساحل - شبرا', 'السلام', 'المرج', 'حلوان', 'بنى سويف', 'ببا',
#        'الفشن', 'إهناسيا', 'سمسطا', 'ناصر', 'الواسطى', 'كفر سعد',
#        'كفر البطيخ', 'كفر الغاب', 'دمياط الجديدة', 'دمياط',
#        'ميت أبو غالب', 'رأس البر', 'الزرقا', 'الوسطانى', 'فارسكور',
#        'الروضة', 'الباجور', 'تلا', 'السادات', 'سرس الليان', 'منوف',
#        'قويسنا', 'الشهداء', 'بركة السبع', 'شبين الكوم', 'أشمون',
#        'المنصورة', 'طلخا', 'أجا', 'ميت غمر', 'دكرنس', 'منية النصر',
#        'ميت سلسيل', 'الجمالية', 'المنزلة', 'نبروه', 'بلقاس', 'شربين',
#        'جمصة', 'السنبلاوين', 'تمى الأمديد', 'بنى عبيد'], dtype=object)

# %%
data['governate'].unique()
# Out:
# array(['القاهرة', 'بنى سويف', 'دمياط', 'المنوفية', 'الدقهلية'],
#       dtype=object)

# %%
data['governate']=data['governate'].str.strip()
data['governate'].unique()
# Out:
# array(['القاهرة', 'بنى سويف', 'دمياط', 'المنوفية', 'الدقهلية'],
#       dtype=object)

# %%
data['station_name'].unique()
# Out:
# array(['عبود', 'السلام', 'المرج', 'عين حلوان', 'بنى سويف', 'ببا', 'الفشن',
#        'إهناسيا', 'سمسطا', 'ناصر ', 'الواسطى', 'كفر سعد', 'الوسطانى',
#        'كفر الغاب', 'رأس البر', 'كفر البطيخ', 'أم الرضا', 'كفر الشيخ',
#        'ميت أبو غالب', 'دمياط', 'دمياط الجديدة', 'الزرقا', 'فارسكور',
#        'الروضة', 'الباجور', 'تلا', 'زرقان', 'زاوية بمم', 'كفر داوود',
#        'الخطاطبة', 'السادات', 'سرس الليان', 'منوف', 'قويسنا', 'ميت بره',
#        'الشهداء', 'نادر', 'العراقية', 'بركة السبع', 'كفر هلال',
#        'شبين الكوم', 'أشمون', 'سنتريس', 'شنشور', 'الرملة', 'طليا',
#        'ساقية أبو شعرة', 'الأتوبيس الجديد', 'قولونجيل',
#        'موقف سندوب العمومى', 'كوم الدربى', 'طناح', 'ميت خميس',
#        'الموقف الجديد', 'موقف ديمره', 'موقف بطره', 'موقف ميت عنتر',
#        'موقف ميت الكرما', 'موقف المنصورة', 'بحور كوبرى العاشر',
#        'أمام نفق السكة الجديد', 'أمام الإدارة الزراعية',
#        'محطة الأتوبيس القديم', 'تقاطع 26 يوليو', 'مصر للسياحة',
# ...

# %%
data['station_name']=data['station_name'].str.strip()
data['station_name'].unique()
# Out:
# array(['عبود', 'السلام', 'المرج', 'عين حلوان', 'بنى سويف', 'ببا', 'الفشن',
#        'إهناسيا', 'سمسطا', 'ناصر', 'الواسطى', 'كفر سعد', 'الوسطانى',
#        'كفر الغاب', 'رأس البر', 'كفر البطيخ', 'أم الرضا', 'كفر الشيخ',
#        'ميت أبو غالب', 'دمياط', 'دمياط الجديدة', 'الزرقا', 'فارسكور',
#        'الروضة', 'الباجور', 'تلا', 'زرقان', 'زاوية بمم', 'كفر داوود',
#        'الخطاطبة', 'السادات', 'سرس الليان', 'منوف', 'قويسنا', 'ميت بره',
#        'الشهداء', 'نادر', 'العراقية', 'بركة السبع', 'كفر هلال',
#        'شبين الكوم', 'أشمون', 'سنتريس', 'شنشور', 'الرملة', 'طليا',
#        'ساقية أبو شعرة', 'الأتوبيس الجديد', 'قولونجيل',
#        'موقف سندوب العمومى', 'كوم الدربى', 'طناح', 'ميت خميس',
#        'الموقف الجديد', 'موقف ديمره', 'موقف بطره', 'موقف ميت عنتر',
#        'موقف ميت الكرما', 'موقف المنصورة', 'بحور كوبرى العاشر',
#        'أمام نفق السكة الجديد', 'أمام الإدارة الزراعية',
#        'محطة الأتوبيس القديم', 'تقاطع 26 يوليو', 'مصر للسياحة',
# ...

# %%
data['destination'].unique()
# Out:
# array(['دمياط', 'رأس البر', 'كفر الشيخ', 'قلين', 'الحامول', 'بيلا',
#        'بلطيم', 'دسوق', 'فوه', 'مطوبس', 'دمنهور', 'أبو المطامير',
#        'الدلنجات', 'شبراخيت', 'إيتاى البارود', 'مديرية التحرير',
#        'مدينة بدر', 'كوم حمادة', 'طنطا', 'السنطة', 'كفر الزيات',
#        'المحلة الكبرى', 'زفتى', 'شبين الكوم', 'تلا', 'نادر', 'الشهداء',
#        'منوف', 'قويسنا', 'بركة السبع', 'الزقازيق', 'أبو حماد',
#        'منيا القمح', 'بلبيس', 'ديرب نجم', 'فاقوس', 'أبو كبير', 'ههيا',
#        'كفر صقر', 'الإبراهيمية', 'الحسينية', 'أولاد صقر', 'المنصورة',
#        'دكرنس', 'السنبلاوين', 'شربين', 'المنزلة', 'منية النصر', 'بلقاس',
#        'ميت غمر', 'جمصة', 'الإسكندرية', 'الإسكندرية (مكيف)', 'الفيوم',
#        'يوسف الصديق', 'بنى سويف', 'الواسطى', 'المنيا', 'أسيوط', 'سوهاج',
#        'الوادى الجديد', 'القرين', 'العاشر من رمضان', 'الصالحية الجديدة',
#        'سمنود', 'بسيون', 'أجا', 'أبو حمص', 'حوش عيسى', 'رشيد', 'الرياض',
# ...

# %%
data['destination']=data['destination'].str.strip()
data['destination'].unique()
# Out:
# array(['دمياط', 'رأس البر', 'كفر الشيخ', 'قلين', 'الحامول', 'بيلا',
#        'بلطيم', 'دسوق', 'فوه', 'مطوبس', 'دمنهور', 'أبو المطامير',
#        'الدلنجات', 'شبراخيت', 'إيتاى البارود', 'مديرية التحرير',
#        'مدينة بدر', 'كوم حمادة', 'طنطا', 'السنطة', 'كفر الزيات',
#        'المحلة الكبرى', 'زفتى', 'شبين الكوم', 'تلا', 'نادر', 'الشهداء',
#        'منوف', 'قويسنا', 'بركة السبع', 'الزقازيق', 'أبو حماد',
#        'منيا القمح', 'بلبيس', 'ديرب نجم', 'فاقوس', 'أبو كبير', 'ههيا',
#        'كفر صقر', 'الإبراهيمية', 'الحسينية', 'أولاد صقر', 'المنصورة',
#        'دكرنس', 'السنبلاوين', 'شربين', 'المنزلة', 'منية النصر', 'بلقاس',
#        'ميت غمر', 'جمصة', 'الإسكندرية', 'الإسكندرية (مكيف)', 'الفيوم',
#        'يوسف الصديق', 'بنى سويف', 'الواسطى', 'المنيا', 'أسيوط', 'سوهاج',
#        'الوادى الجديد', 'القرين', 'العاشر من رمضان', 'الصالحية الجديدة',
#        'سمنود', 'بسيون', 'أجا', 'أبو حمص', 'حوش عيسى', 'رشيد', 'الرياض',
# ...

# %%
data[data['destination']=='طلمبا بنى عبيد']['destination']='طلمبات بنى عبيد'
data['destination'].unique()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_4412\781952071.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[data['destination']=='طلمبا بنى عبيد']['destination']='طلمبات بنى عبيد'
# array(['دمياط', 'رأس البر', 'كفر الشيخ', 'قلين', 'الحامول', 'بيلا',
#        'بلطيم', 'دسوق', 'فوه', 'مطوبس', 'دمنهور', 'أبو المطامير',
#        'الدلنجات', 'شبراخيت', 'إيتاى البارود', 'مديرية التحرير',
#        'مدينة بدر', 'كوم حمادة', 'طنطا', 'السنطة', 'كفر الزيات',
#        'المحلة الكبرى', 'زفتى', 'شبين الكوم', 'تلا', 'نادر', 'الشهداء',
#        'منوف', 'قويسنا', 'بركة السبع', 'الزقازيق', 'أبو حماد',
#        'منيا القمح', 'بلبيس', 'ديرب نجم', 'فاقوس', 'أبو كبير', 'ههيا',
#        'كفر صقر', 'الإبراهيمية', 'الحسينية', 'أولاد صقر', 'المنصورة',
# ...

# %%
data.to_excel('Sikka_data.xlsx',index=False)

# %%
lst=['الفيوم','الفيوم (مكيف)']
print([x.split()[0] for x in lst])
# Out:
# ['الفيوم', 'الفيوم']
